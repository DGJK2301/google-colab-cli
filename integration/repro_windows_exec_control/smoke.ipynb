# %%
# @title Selected Cell
import platform
print('WINDOWS_CELL_SELECTION_OK', platform.python_version())

# %%
# @title Unselected Cell
raise RuntimeError('UNSELECTED_CELL_EXECUTED')

# %%
# @title Error Cell
raise RuntimeError('EXPECTED_FAIL_ON_ERROR')
